# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
total_duration = 30
clip_len = 3

# %%
correct_spec = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/6.npy'))
spec = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/20.npy'))
spec2 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/29.npy'))
spec3 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/38.npy'))
spec4 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/39.npy'))
spec5 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/41.npy'))
spec6 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/42.npy'))
spec7 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/45.npy'))
spec8 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/47.npy'))
spec9 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/51.npy'))
spec10 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/56.npy'))
spec11 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/58.npy'))
spec12 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/61.npy'))
spec13 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/62.npy'))
spec14 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/66.npy'))
spec15 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/77.npy'))
spec16 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/84.npy'))
spec17 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/92.npy'))
spec18 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/94.npy'))
spec19 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/95.npy'))
spec20 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/98.npy'))
spec21 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/105.npy'))
spec22 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/113.npy'))
spec23 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/128.npy'))
spec24 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/133.npy'))
spec25 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/139.npy'))
spec26 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/142.npy'))
spec27 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/152.npy'))
spec28 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/162.npy'))
spec29 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/171.npy'))
spec30 = torch.from_numpy(np.load('ADL_DCASE_DATA/evaluation/audio/189.npy'))

time_steps = spec.size(-1)
num_clips = total_duration // clip_len
time_interval = int(time_steps // num_clips)
correct_spec = spec[:, :time_interval]
spec = spec[:, :time_interval]
spec2 = spec2[:, :time_interval]
spec3 = spec3[:, :time_interval]
spec4 = spec4[:, :time_interval]
spec5 = spec5[:, :time_interval]
spec6 = spec6[:, :time_interval]
spec7 = spec7[:, :time_interval]
spec8 = spec8[:, :time_interval]
spec9 = spec9[:, :time_interval]
spec10 = spec10[:, :time_interval]
spec11 = spec11[:, :time_interval]
spec12 = spec12[:, :time_interval]
spec13 = spec13[:, :time_interval]
spec14 = spec14[:, :time_interval]
spec15 = spec15[:, :time_interval]
spec16 = spec16[:, :time_interval]
spec17 = spec17[:, :time_interval]
spec18 = spec18[:, :time_interval]
spec19 = spec19[:, :time_interval]
spec20 = spec20[:, :time_interval]
spec21 = spec21[:, :time_interval]
spec22 = spec22[:, :time_interval]
spec23 = spec23[:, :time_interval]
spec24 = spec24[:, :time_interval]
spec25 = spec25[:, :time_interval]
spec26 = spec26[:, :time_interval]
spec27 = spec27[:, :time_interval]
spec28 = spec28[:, :time_interval]
spec29 = spec29[:, :time_interval]
spec30 = spec30[:, :time_interval]

# %%
"""







idx: 92, Thought cafe/restaurant was grocery_store
idx: 94, Thought residential_area was park
idx: 95, Thought home was library
idx: 98, Thought cafe/restaurant was grocery_store
idx: 105, Thought metro_station was grocery_store
idx: 113, Thought library was home
idx: 128, Thought cafe/restaurant was grocery_store
idx: 133, Thought beach was forest_path
idx: 139, Thought grocery_store was home
idx: 142, Thought train was tram
idx: 152, Thought metro_station was grocery_store
idx: 162, Thought cafe/restaurant was office
idx: 171, Thought beach was forest_path

idx: 195, Thought park was residential_area
idx: 197, Thought tram was train
idx: 201, Thought residential_area was park
idx: 203, Thought library was office
idx: 207, Thought bus was train
idx: 215, Thought city_center was park
idx: 217, Thought train was cafe/restaurant
idx: 225, Thought tram was beach
idx: 237, Thought tram was train
idx: 238, Thought residential_area was beach
idx: 247, Thought library was home
idx: 271, Thought residential_area was park
idx: 277, Thought residential_area was park
idx: 278, Thought cafe/restaurant was home
idx: 288, Thought library was office
idx: 302, Thought cafe/restaurant was office
idx: 306, Thought park was residential_area
idx: 331, Thought park was train
idx: 333, Thought grocery_store was home
idx: 345, Thought library was home
idx: 360, Thought train was cafe/restaurant
idx: 362, Thought beach was residential_area
idx: 364, Thought library was home
idx: 378, Thought bus was tram
"""
# Out:
# '\n\n\n\n\n\n\n\nidx: 92, Thought cafe/restaurant was grocery_store\nidx: 94, Thought residential_area was park\nidx: 95, Thought home was library\nidx: 98, Thought cafe/restaurant was grocery_store\nidx: 105, Thought metro_station was grocery_store\nidx: 113, Thought library was home\nidx: 128, Thought cafe/restaurant was grocery_store\nidx: 133, Thought beach was forest_path\nidx: 139, Thought grocery_store was home\nidx: 142, Thought train was tram\nidx: 152, Thought metro_station was grocery_store\nidx: 162, Thought cafe/restaurant was office\nidx: 171, Thought beach was forest_path\nidx: 189, Thought library was home\nidx: 195, Thought park was residential_area\nidx: 197, Thought tram was train\nidx: 201, Thought residential_area was park\nidx: 203, Thought library was office\nidx: 207, Thought bus was train\nidx: 215, Thought city_center was park\nidx: 217, Thought train was cafe/restaurant\nidx: 225, Thought tram was beach\nidx: 237, Thought tram was train\nidx: 238, Thought r
# ...

# %%
plt.imshow(spec.numpy())
print('idx: 20, Thought train was cafe/restaurant')
# Out:
# idx: 20, Thought train was cafe/restaurant

# %%
plt.imshow(spec2.numpy())
print('idx: 29, Thought car was train')
# Out:
# idx: 29, Thought car was train

# %%
plt.xlabel('Time')
plt.ylabel('Frequency (KHz)')
plt.imshow(spec3.numpy())
print('idx: 38, Thought library was office')
# Out:
# idx: 38, Thought library was office

# %%
plt.xlabel('Time')
plt.ylabel('Frequency (KHz)')
plt.imshow(correct_spec.numpy())
print('Correctly predicted library')
# Out:
# Correctly predicted library

# %%
plt.imshow(spec4.numpy())
print('idx: 39, Thought cafe/restaurant was home')
# Out:
# idx: 39, Thought cafe/restaurant was home

# %%
plt.imshow(spec5.numpy())
print('idx: 41, Thought train was cafe/restaurant')
# Out:
# idx: 41, Thought train was cafe/restaurant

# %%
plt.imshow(spec6.numpy())
print('idx: 42, Thought library was office')
# Out:
# idx: 42, Thought library was office

# %%
plt.imshow(spec7.numpy())
print('idx: 45, Thought car was train')
# Out:
# idx: 45, Thought car was train

# %%
plt.imshow(spec8.numpy())
print('idx: 47, Thought library was office')
# Out:
# idx: 47, Thought library was office

# %%
plt.imshow(spec9.numpy())
print('idx: 51, Thought home was library')
# Out:
# idx: 51, Thought home was library

# %%
plt.imshow(spec10.numpy())
print('idx: 56, Thought park was residential_area')
# Out:
# idx: 56, Thought park was residential_area

# %%
plt.imshow(spec11.numpy())
print('idx: 58, Thought cafe/restaurant was grocery_store')
# Out:
# idx: 58, Thought cafe/restaurant was grocery_store

# %%
plt.imshow(spec12.numpy())
print('idx: 61, Thought cafe/restaurant was home')
# Out:
# idx: 61, Thought cafe/restaurant was home

# %%
plt.imshow(spec13.numpy())
print('idx: 62, Thought residential_area was park')
# Out:
# idx: 62, Thought residential_area was park

# %%
plt.imshow(spec14.numpy())
print('idx: 66, Thought residential_area was office')
# Out:
# idx: 66, Thought residential_area was office

# %%
plt.imshow(spec15.numpy())
print('idx: 77, Thought metro_station was grocery_store')
# Out:
# idx: 77, Thought metro_station was grocery_store

# %%
plt.imshow(spec16.numpy())
print('idx: 84, Thought tram was bus')
# Out:
# idx: 84, Thought tram was bus

# %%
plt.imshow(spec30.numpy())
print('idx: 189, Thought library was home')
# Out:
# idx: 189, Thought library was home
