# %%
import torch
import os
from torch.utils.data import DataLoader
from torch.optim import Adam
import torch.nn.functional as F
import pandas as pd

from torch.utils.tensorboard import SummaryWriter

from dataset import DCASE
from Trainer import Trainer
from CNN import CNN

# if torch.cuda.is_available():
#     device = torch.device("cuda")
# else:
device = torch.device("cpu")

clip_length = 3
batch_size = 1
root_dir_train = os.getcwd() + '/ADL_DCASE_DATA/dev'
root_dir_val = os.getcwd() + '/ADL_DCASE_DATA/evaluation'

# %%
summary_writer = SummaryWriter(str(os.getcwd()), flush_secs=1)

# %%
train_dataset = DCASE(root_dir_train, clip_length)
val_dataset = DCASE(root_dir_val, clip_length)

model = CNN(clip_length, train_dataset.get_num_clips(), batch_size=1)

train_loader = DataLoader(train_dataset, shuffle=True, batch_size = batch_size)
val_loader = DataLoader(val_dataset, shuffle=False, batch_size = batch_size)
optim = Adam(model.parameters(), lr=3e-4)

trainer = Trainer(
    model, train_loader, val_loader, F.cross_entropy, optim, summary_writer, device
)

# %%
trainer.train(2, 2)
# Out:
#   0%|          | 0/2 [00:00<?, ? epoch/s]
#
#
#   0%|          | 0/154 [00:00<?, ? audio seq/s]
#
#
#   1%|          | 1/154 [00:00<00:18,  8.38 audio seq/s]
#
#
#   1%|▏         | 2/154 [00:00<00:19,  7.81 audio seq/s]
#
#
#   2%|▏         | 3/154 [00:00<00:20,  7.46 audio seq/s]
#
#
#   3%|▎         | 4/154 [00:00<00:19,  7.51 audio seq/s]
#
#
#   3%|▎         | 5/154 [00:00<00:19,  7.57 audio seq/s]
#
#
#   4%|▍         | 6/154 [00:00<00:19,  7.60 audio seq/s]
#
#
#   5%|▍         | 7/154 [00:00<00:19,  7.36 audio seq/s]
#
#
#   5%|▌         | 8/154 [00:01<00:19,  7.62 audio seq/s]
#
#
#   6%|▌         | 9/154 [00:01<00:18,  7.84 audio seq/s]
#
#
#   6%|▋         | 10/154 [00:01<00:17,  8.00 audio seq/s]
#
#
#   7%|▋         | 11/154 [00:01<00:17,  8.08 audio seq/s]
#
#
#   8%|▊         | 12/154 [00:01<00:17,  8.19 audio seq/s]
#
#
#   8%|▊         | 13/154 [00:01<00:17,  8.07 audio seq/s]
#
#
#   9%|▉         | 14/154 [00:01<00:18,  7.69 audio seq/s]
#
#
#  10%|▉         | 15/154 [00:01<00:17,  7.87 audio seq/s]
#
#
#  10%|█         | 16/154 [00:02<00:17,  7.81 audio seq/s]
#
#
#  11%|█         | 17/154 [00:02<00:17,  7.64 audio seq/s]
#
#
#  12%|█▏        | 18/154 [00:02<00:17,  7.76 audio seq/s]
#
#
#  12%|█▏        | 19/154 [00:02<00:16,  7.97 audio seq/s]
#
#
#  13%|█▎        | 20/154 [00:02<00:17,  7.49 audio seq/s]
#
#
#  14%|█▎        | 21/154 [00:02<00:18,  7.26 audio seq/s]
#
#
#  14%|█▍        | 22/154 [00:02<00:17,  7.35 audio seq/s]
#
#
#  15%|█▍        | 23/154 [00:03<00:17,  7.36 audio seq/s]
#
#
#  16%|█▌        | 24/154 [00:03<00:17,  7.42 audio seq/s]
#
#
#  16%|█▌        | 25/154 [00:03<00:17,  7.45 audio seq/s]
#
#
#  17%|█▋        | 26/154 [00:03<00:17,  7.45 audio seq/s]
#
#
#  18%|█▊        | 27/154 [00:03<00:16,  7.49 audio seq/s]
#
#
#  18%|█▊        | 28/154 [00:03<00:16,  7.45 audio seq/s]
#
#
#  19%|█▉        | 29/154 [00:03<00:16,  7.57 audio seq/s]
#
#
#  19%|█▉        | 30/154 [00:03<00:16,  7.61 audio seq/s]
#
#
#  20%|██        | 31/154 [00:04<00:16,  7.61 audio seq/s]
#
#
#  21%|██        | 32/154 [00:04<00:15,  7.65 audio seq/s]
#
#
#  21%|██▏       | 33/154 [00:04<00:15,  7.70 audio seq/s]
#
#
#  22%|██▏       | 34/154 [00:04<00:15,  7.66 audio seq/s]
#
#
#  23%|██▎       | 35/154 [00:04<00:15,  7.50 audio seq/s]
#
#
#  23%|██▎       | 36/154 [00:04<00:16,  7.35 audio seq/s]
#
#
#  24%|██▍       | 37/154 [00:04<00:15,  7.41 audio seq/s]
#
#
#  25%|██▍       | 38/154 [00:05<00:16,  7.16 audio seq/s]
#
#
#  25%|██▌       | 39/154 [00:05<00:15,  7.19 audio seq/s]
#
#
#  26%|██▌       | 40/154 [00:05<00:16,  6.76 audio seq/s]
#
#
#  27%|██▋       | 41/154 [00:05<00:16,  6.82 audio seq/s]
#
#
#  27%|██▋       | 42/154 [00:05<00:16,  6.66 audio seq/s]
#
#
#  28%|██▊       | 43/154 [00:05<00:16,  6.81 audio seq/s]
#
#
#  29%|██▊       | 44/154 [00:05<00:16,  6.76 audio seq/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-58ff56577735> in <module>
# ----> 1 trainer.train(2, 2)
#
# ~/COMSM0045/coursework/Trainer.py in train(self, epochs, val_frequency, print_frequency, log_frequency, start_epoch)
#     116         ):
#     117
# --> 118             train_results = self._train_step()
#     119             loss = train_results['loss']
#     120             accuracy = train_results['accuracy']
#
# ~/COMSM0045/coursework/Trainer.py in _train_step(self)
#      61
#      62             loss = step_results['loss']
# ---> 63             loss.backward()
#      64
#      65             self.optimizer.step()
#
# /mnt/storage/software/languages/anaconda/Anaconda3-2019.07/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     116                 products. Defaults to ``False``.
#     117         """
# --> 118         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     119
#     120     def register_hook(self, hook):
#
# /mnt/storage/software/languages/anaconda/Anaconda3-2019.07/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
trainer.print_per_class_accuracy()
